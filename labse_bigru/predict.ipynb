# %%
from tensorflow.keras.models import load_model
import numpy as np

# Modeli yükle
model = load_model('/path/to/my_model.keras')

# Yeni veriler (örnek)
X_new = np.array([...])  # Doğru şekle uygun embedding dizisi

# Tahmin yap
predictions = model.predict(X_new)
pred_labels = (predictions > 0.5).astype(int)

print(pred_labels)
